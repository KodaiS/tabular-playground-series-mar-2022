# %% [markdown]
# # mount drive

# %%
use_colaboratory = True
if use_colaboratory:
    import os
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir('/content/drive/MyDrive/kaggle/tabular-playground-series-mar-2022/notebook')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import packages
import datetime
import math
import pickle

import lightgbm as lgb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import OneHotEncoder

# %matplotlib inline

# %%
# load data
train = pd.read_csv("../input/train.csv", index_col="row_id")
test = pd.read_csv("../input/test.csv", index_col="row_id")

# %%
data = pd.concat([train, test])
data["time"] = pd.to_datetime(data["time"])

# %%
data["hour"] = data["time"].dt.hour
data["minute"] = data["time"].dt.minute
data["weekday"] = data["time"].dt.weekday
data["isAM"] = data.hour < 12
data["isweekend"] = data.weekday >= 5

# %%
ld_col = ["x", "y", "direction"]

weekday_mean = data.iloc[:len(train)].groupby(ld_col + ["weekday"]).congestion.mean()
hour_mean = data.iloc[:len(train)].groupby(ld_col + ["hour"]).congestion.mean()

weekday_mean.colmuns = ["weekday_mean"]
hour_mean.colmuns = ["hour_mean"]

data = data.merge(weekday_mean, how="left", left_on=ld_col+["weekday"], right_index=True, suffixes=("", "_weekday_mean"))
data = data.merge(hour_mean, how="left", left_on=ld_col+["hour"], right_index=True, suffixes=("", "_hour_mean"))
data.head()
# Out:
#              time  x  y direction  congestion  hour  minute  weekday  isAM  \
# row_id
# 0      1991-04-01  0  0        EB        70.0     0       0        0     1
# 1      1991-04-01  0  0        NB        49.0     0       0        0     1
# 2      1991-04-01  0  0        SB        24.0     0       0        0     1
# 3      1991-04-01  0  1        EB        18.0     0       0        0     1
# 4      1991-04-01  0  1        NB        60.0     0       0        0     1
#
#         isweekend  congestion_weekday_mean  congestion_hour_mean
# row_id
# 0               0                48.381551             40.708561
# 1               0                39.502621             38.258652
# 2               0                50.679245             42.615665
# 3               0                27.278302             23.601093
# 4               0                69.612159             67.551913

# %%
train = data.iloc[:len(train)]
test = data.iloc[len(train):]

# %%
xs = train.x.unique().tolist()
ys = train.y.unique().tolist()
dirs = train.direction.unique().tolist()

feature_col = ["hour", "minute", "weekday", "isAM", "isweekend", "congestion_weekday_mean", "congestion_hour_mean"]

params = {
    "objective": "regression",
    "metric": "mae",
    "learning_rate": 0.05,
}

oof_train = np.zeros((len(train), ))
oof_idx = []
all_models = {}
all_y_preds = {}

for x in xs:
    for y in ys:
        for dir in dirs:
            loc_dir = (x, y, dir)
            print("======== loop: {} ========".format(loc_dir))

            locdir_X_train = train[(train.x == x) & (train.y == y) & (train.direction == dir)][feature_col]
            locdir_y_train = train[(train.x == x) & (train.y == y) & (train.direction == dir)]["congestion"]
            locdir_X_test = test[(test.x == x) & (test.y == y) & (test.direction == dir)][feature_col]

            # loc & dir の組み合わせが存在しないときは処理しない
            if locdir_X_train.shape[0] == 0:
                print("{} is nothing".format(loc_dir))
                continue

            cv = TimeSeriesSplit(n_splits=5)

            y_preds = []
            models = []

            for fold_idx, (tr_idx, val_idx) in enumerate(cv.split(locdir_X_train)):
                print(f"======== fold: {fold_idx} ========")
                X_tr, X_val = locdir_X_train.iloc[tr_idx], locdir_X_train.iloc[val_idx]
                y_tr, y_val = locdir_y_train.iloc[tr_idx], locdir_y_train.iloc[val_idx]
                
                lgb_train = lgb.Dataset(X_tr, y_tr)
                lgb_eval = lgb.Dataset(X_val, y_val, reference=lgb_train)
                
                model = lgb.train(params, lgb_train,
                                valid_sets=[lgb_train, lgb_eval],
                                verbose_eval=10,
                                num_boost_round=1000,
                                early_stopping_rounds=10)
                
                oof_train[X_val.index] = \
                    model.predict(X_val, num_iteration=model.best_iteration)

                oof_idx += X_val.index.tolist()

                y_pred = model.predict(locdir_X_test, num_iteration=model.best_iteration)

                y_preds.append(y_pred)
                models.append(model)
            
            all_y_preds[loc_dir] = y_preds
            all_models[loc_dir] = models
# Out:
# ======== loop: (0, 0, 'EB') ========
# ======== fold: 0 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 8.3173	valid_1's l1: 9.76613
# [20]	training's l1: 7.93986	valid_1's l1: 9.74217
# Early stopping, best iteration is:
# [16]	training's l1: 8.06932	valid_1's l1: 9.73462
# ======== fold: 1 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 9.01351	valid_1's l1: 9.8278
# [20]	training's l1: 8.74597	valid_1's l1: 9.62383
# [30]	training's l1: 8.58955	valid_1's l1: 9.52621
# [40]	training's l1: 8.4766	valid_1's l1: 9.48188
# [50]	training's l1: 8.40155	valid_1's l1: 9.46469
# [60]	training's l1: 8.3439	valid_1's l1: 9.46032
# [70]	training's l1: 8.30911	valid_1's l1: 9.46044
# Early stopping, best iteration is:
# [63]	training's l1: 8.33401	valid_1's l1: 9.45645
# ======== fold: 2 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 9.23507	valid_1's l1: 9.47297
# [20]	training's l1: 8.96654	valid_1's l1: 9.23039
# [30]	training's l1: 8.8323	valid_1's l1: 9.12418
# [40]	training's l1: 8.74632	valid_1's l1: 9.07801
# [50]	training's l1: 8.68895	valid_1's l1: 9.04643
# [60]	training's l1: 8.64878	valid_1's l1: 9.02698
# [70]	training's l1: 8.62011	valid_1's l1: 9.02791
# Early stopping, best iteration is:
# [64]	training's l1: 8.63708	valid_1's l1: 9.02515
# ======== fold: 3 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 9.29494	valid_1's l1: 9.33466
# [20]	training's l1: 9.02665	valid_1's l1: 9.08641
# [30]	training's l1: 8.88757	valid_1's l1: 9.01234
# [40]	training's l1: 8.80895	valid_1's l1: 8.98171
# [50]	training's l1: 8.75531	valid_1's l1: 8.9697
# [60]	training's l1: 8.71868	valid_1's l1: 8.96343
# [70]	training's l1: 8.68573	valid_1's l1: 8.9657
# Early stopping, best iteration is:
# [61]	training's l1: 8.71299	valid_1's l1: 8.96301
# ======== fold: 4 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 9.28192	valid_1's l1: 9.74398
# [20]	training's l1: 9.00586	valid_1's l1: 9.71295
# Early stopping, best iteration is:
# [16]	training's l1: 9.08751	valid_1's l1: 9.70398
# ======== loop: (0, 0, 'NB') ========
# ======== fold: 0 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 7.14372	valid_1's l1: 7.26949
# [20]	training's l1: 6.78462	valid_1's l1: 7.07344
# [30]	training's l1: 6.57579	valid_1's l1: 6.99934
# [40]	training's l1: 6.45759	valid_1's l1: 6.95891
# [50]	training's l1: 6.3856	valid_1's l1: 6.95271
# [60]	training's l1: 6.32702	valid_1's l1: 6.94573
# Early stopping, best iteration is:
# [58]	training's l1: 6.33674	valid_1's l1: 6.94366
# ======== fold: 1 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 7
# ======== fold: 2 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 9.69645	valid_1's l1: 10.0901
# [20]	training's l1: 9.2928	valid_1's l1: 9.79734
# [30]	training's l1: 9.08517	valid_1's l1: 9.67303
# [40]	training's l1: 8.96445	valid_1's l1: 9.61878
# [50]	training's l1: 8.88333	valid_1's l1: 9.59957
# [60]	training's l1: 8.82514	valid_1's l1: 9.58554
# [70]	training's l1: 8.77813	valid_1's l1: 9.5744
# [80]	training's l1: 8.74435	valid_1's l1: 9.5755
# Early stopping, best iteration is:
# [72]	training's l1: 8.7711	valid_1's l1: 9.57238
# ======== fold: 3 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 9.76315	valid_1's l1: 10.1934
# [20]	training's l1: 9.38363	valid_1's l1: 9.89833
# [30]	training's l1: 9.20234	valid_1's l1: 9.7562
# [40]	training's l1: 9.09861	valid_1's l1: 9.69033
# [50]	training's l1: 9.04272	valid_1's l1: 9.64756
# [60]	training's l1: 8.99811	valid_1's l1: 9.62712
# [70]	training's l1: 8.96406	valid_1's l1: 9.61671
# [80]	training's l1: 8.93549	valid_1's l1: 9.61106
# [90]	training's l1: 8.91478	valid_1's l1: 9.60387
# [100]	training's l1: 8.89674	valid_1's l1: 9.60161
# [110]	training's l1: 8.87883	valid_1's l1: 9.60864
# Early stopping, best iteration is:
# [101]	training's l1: 8.89516	valid_1's l1: 9.60075
# ======== fold: 4 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 9.82483	valid_1's l1: 10.0978
# [20]	training's l1: 9.4556	valid_1's l1: 9.94974
# [30]	training's l1: 9.28358	valid_1's l1: 9.93711
# [40]	training's l1: 9.1936	valid_1's l1: 9.94939
# Early stopping, best iteration is:
# [32]	training's l1: 9.2615	valid_1's l1: 9.93517
# ======== loop: (0, 0, 'WB') ========
# (0, 0, 'WB') is nothing
# ======== loop: (0, 0, 'NE') ========
# (0, 0, 'NE') is nothing
# ======== loop: (0, 0, 'SW') ========
# (0, 0, 'SW') is nothing
# ======== loop: (0, 0, 'NW') ========
# (0, 0, 'NW') is nothing
# ======== loop: (0, 0, 'SE') ========
# (0, 0, 'SE') is nothing
# ======== loop: (0, 1, 'EB') ========
# ======== fold: 0 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 5.3637	valid_1's l1: 5.65067
# [20]	training's l1: 5.13789	valid_1's l1: 5.4961
# [30]	training's l1: 5.01471	valid_1's l1: 5.43569
# [40]	training's l1: 4.93396	valid_1's l1: 5.40678
# [50]	training's l1: 4.8713	valid_1's l1: 5.39301
# [60]	training's l1: 4.83284	valid_1's l1: 5.38627
# Early stopping, best iteration is:
# [56]	training's l1: 4.84368	valid_1's l1: 5.38452
# ======== fold: 1 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 5.45898	valid_1's l1: 5.54907
# [20]	training's l1: 5.2324	valid_1's l1: 5.36581
# [30]	training's l1: 5.10795	valid_1's l1: 5.28917
# [40]	training's l1: 5.03656	valid_1's l1: 5.25173
# [50]	training's l1: 4.97838	valid_1's l1: 5.23428
# [60]	training's l1: 4.94051	valid_1's l1: 5.22701
# [70]	training's l1: 4.90763	valid_1's l1: 5.21137
# [80]	training's l1: 4.88282	valid_1's l1: 5.20657
# [90]	training's l1: 4.85816	valid_1's l1: 5.20145
# [100]	training's l1: 4.83675	valid_1's l1: 5.20069
# [110]	training's l1: 4.82004	valid_1's l1: 5.19704
# [120]	training's l1: 4.80829	valid_1's l1: 5.1989
# Early stopping, best iteration is:
# [111]	training's l1: 4.81863	valid_1's l1: 5.19687
# ======== fold: 2 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 5
# ======== fold: 2 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 8.7337	valid_1's l1: 9.28375
# [20]	training's l1: 8.4291	valid_1's l1: 9.01567
# [30]	training's l1: 8.27353	valid_1's l1: 8.89893
# [40]	training's l1: 8.19614	valid_1's l1: 8.86053
# [50]	training's l1: 8.14136	valid_1's l1: 8.84856
# [60]	training's l1: 8.10101	valid_1's l1: 8.85181
# Early stopping, best iteration is:
# [55]	training's l1: 8.11911	valid_1's l1: 8.84637
# ======== fold: 3 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 8.82796	valid_1's l1: 9.00841
# [20]	training's l1: 8.52116	valid_1's l1: 8.67099
# [30]	training's l1: 8.3897	valid_1's l1: 8.5282
# [40]	training's l1: 8.32219	valid_1's l1: 8.46532
# [50]	training's l1: 8.28215	valid_1's l1: 8.43796
# [60]	training's l1: 8.25463	valid_1's l1: 8.42667
# [70]	training's l1: 8.23176	valid_1's l1: 8.41486
# [80]	training's l1: 8.21594	valid_1's l1: 8.4089
# [90]	training's l1: 8.19961	valid_1's l1: 8.40432
# [100]	training's l1: 8.18664	valid_1's l1: 8.40663
# Early stopping, best iteration is:
# [93]	training's l1: 8.19606	valid_1's l1: 8.40393
# ======== fold: 4 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 8.85258	valid_1's l1: 9.19139
# [20]	training's l1: 8.53459	valid_1's l1: 9.20465
# Early stopping, best iteration is:
# [13]	training's l1: 8.72996	valid_1's l1: 9.18139
# ======== loop: (0, 1, 'NE') ========
# (0, 1, 'NE') is nothing
# ======== loop: (0, 1, 'SW') ========
# (0, 1, 'SW') is nothing
# ======== loop: (0, 1, 'NW') ========
# (0, 1, 'NW') is nothing
# ======== loop: (0, 1, 'SE') ========
# (0, 1, 'SE') is nothing
# ======== loop: (0, 2, 'EB') ========
# ======== fold: 0 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 4.63358	valid_1's l1: 4.96092
# [20]	training's l1: 4.40492	valid_1's l1: 4.83425
# [30]	training's l1: 4.26798	valid_1's l1: 4.76963
# [40]	training's l1: 4.18395	valid_1's l1: 4.74155
# [50]	training's l1: 4.13343	valid_1's l1: 4.73412
# [60]	training's l1: 4.09225	valid_1's l1: 4.7258
# [70]	training's l1: 4.06035	valid_1's l1: 4.72279
# [80]	training's l1: 4.03468	valid_1's l1: 4.72578
# Early stopping, best iteration is:
# [71]	training's l1: 4.0583	valid_1's l1: 4.72242
# ======== fold: 1 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 4.73662	valid_1's l1: 5.13054
# [20]	training's l1: 4.50931	valid_1's l1: 4.90863
# [30]	training's l1: 4.39072	valid_1's l1: 4.81856
# [40]	training's l1: 4.3308	valid_1's l1: 4.77338
# [50]	training's l1: 4.29498	valid_1's l1: 4.74975
# [60]	training's l1: 4.26853	valid_1's l1: 4.73839
# [70]	training's l1: 4.24478	valid_1's l1: 4.73503
# [80]	training's l1: 4.22222	valid_1's l1: 4.73591
# Early stopping, best iteration is:
# [71]	training's l1: 4.24168	valid_1's l1: 4.73328
# ======== fold: 2 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1:
========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 7.60951	valid_1's l1: 7.46716
# [20]	training's l1: 6.72753	valid_1's l1: 6.84873
# [30]	training's l1: 6.36766	valid_1's l1: 6.65449
# [40]	training's l1: 6.21837	valid_1's l1: 6.59353
# [50]	training's l1: 6.14776	valid_1's l1: 6.58536
# Early stopping, best iteration is:
# [46]	training's l1: 6.1709	valid_1's l1: 6.58401
# ======== loop: (0, 2, 'WB') ========
# ======== fold: 0 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 3.45978	valid_1's l1: 3.54641
# [20]	training's l1: 3.22089	valid_1's l1: 3.35445
# [30]	training's l1: 3.11223	valid_1's l1: 3.29748
# [40]	training's l1: 3.04699	valid_1's l1: 3.27771
# [50]	training's l1: 3.01048	valid_1's l1: 3.27874
# Early stopping, best iteration is:
# [44]	training's l1: 3.03067	valid_1's l1: 3.27497
# ======== fold: 1 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 3.41584	valid_1's l1: 3.74906
# [20]	training's l1: 3.1919	valid_1's l1: 3.554
# [30]	training's l1: 3.10658	valid_1's l1: 3.48306
# [40]	training's l1: 3.06721	valid_1's l1: 3.45333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-e70f8092fde2> in <module>()
#      48                                 verbose_eval=10,
#      49                                 num_boost_round=1000,
# ---> 50                                 early_stopping_rounds=10)
#      51
#      52                 oof_train[X_val.index] =                     model.predict(X_val, num_iteration=model.best_iteration)
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     216                                     evaluation_result_list=None))
#     217
# --> 218         booster.update(fobj=fobj)
#     219
#     220         evaluation_result_list = []
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1800             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1801                 self.handle,
# -> 1802                 ctypes.byref(is_finished)))
#    1803             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1804             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(8, 4))
plt.hist(oof_train[oof_idx], bins=100, label="oof", alpha=0.5)
plt.hist(train.iloc[oof_idx].congestion, bins=100, label="y_train", alpha=0.5)
plt.legend()

# %%
scores = {}

for ld, ms in all_models.items():
    scores[ld] = ms[-1].best_score["valid_1"]["l1"]

score = sum(scores.values()) / len(scores)
print("=== CV scores ===")
print(scores)
print(score)

# %%
with open("../output/all_y_preds_008.pickle", "wb") as f:
    pickle.dump(all_y_preds, f)

with open("../output/all_models_008.pickle", "wb") as f:
    pickle.dump(all_models, f)

with open("../output/oof_train_008.pickle", "wb") as f:
    pickle.dump(oof_train, f)

with open("../output/oof_idx_008.pickle", "wb") as f:
    pickle.dump(oof_idx, f)

# %%
sub_pred = test.copy()[["x", "y", "direction", "congestion"]]

# %%
for (x, y, dir), y_preds in all_y_preds.items():
    sub_pred.loc[((test.x == x) & (test.y == y) & (test.direction == dir)), ["congestion"]] = y_preds[-1]

# %%
submission = pd.read_csv("../input/sample_submission.csv")
submission.congestion = sub_pred.congestion.to_numpy()
submission.to_csv("../submit/submission_008.csv", index=False)

# %%
for key, models in all_models.items():
    f_importance = models[-1].feature_importance()
    f_importance = f_importance / sum(f_importance)
    df_importance = pd.DataFrame({"feature": feature_col, "importance": f_importance}).sort_values("importance", ascending=False)
    print("==========={}===========".format(key))
    plt.figure(figsize=(6, 3))
    plt.bar(x="feature", height="importance", data=df_importance)
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# ### submit

# %%
import json
with open('../../kaggle.json') as f:
    json_data = json.load(f)
    os.environ["KAGGLE_USERNAME"] = json_data["username"]
    os.environ["KAGGLE_KEY"] = json_data["key"]

# !pip install kaggle --upgrade
# !kaggle -v

# %%
# submission
# !kaggle competitions submit tabular-playground-series-mar-2022 -f ../submit/submission_008.csv -m "008"
