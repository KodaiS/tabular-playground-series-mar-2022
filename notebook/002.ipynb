# %% [markdown]
# # mount drive

# %%
use_colaboratory = True
if use_colaboratory:
    import os
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir('/content/drive/MyDrive/kaggle/tabular-playground-series-mar-2022/notebook')
# Out:
# Mounted at /content/drive

# %%
# import packages
import datetime
import math
import pickle

import lightgbm as lgb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import OneHotEncoder

# %matplotlib inline

# %%
# load data
train = pd.read_csv("../input/train.csv", index_col="row_id")
test = pd.read_csv("../input/test.csv", index_col="row_id")

data = pd.concat([train, test])
data["time"] = pd.to_datetime(data["time"])
data["month"] = data["time"].dt.month
data["day"] = data["time"].dt.day
data["hour"] = data["time"].dt.hour
data["minute"] = data["time"].dt.minute
data["weekday"] = data["time"].dt.weekday
data = pd.get_dummies(data, columns=["direction"])
train = data.iloc[:len(train)]
test = data.iloc[len(train):]

# %%
X_train = train.drop(["time", "congestion"], axis=1)
y_train = train["congestion"]
X_test = test.drop(["time", "congestion"], axis=1)

# %%
direction_col = [col for col in X_train.columns if "direction" in col]
categorical_features = ["x", "y"] + direction_col

y_preds = []
models = []
oof_train = np.zeros((len(X_train),))
cv_idx = {}

cv = TimeSeriesSplit(n_splits=5)

params = {
    "objective": "regression",
    "metric": "mae",
    "learning_rate": 0.05,
}

for fold_idx, (tr_idx, val_idx) in enumerate(cv.split(X_train)):
    cv_idx[fold_idx] = [tr_idx, val_idx]
    print(f"======== fold: {fold_idx} ========")
    X_tr, X_val = X_train.iloc[tr_idx], X_train.iloc[val_idx]
    y_tr, y_val = y_train.iloc[tr_idx], y_train.iloc[val_idx]
    
    lgb_train = lgb.Dataset(X_tr, y_tr,
                            categorical_feature=categorical_features)
    lgb_eval = lgb.Dataset(X_val, y_val, reference=lgb_train,
                           categorical_feature=categorical_features)
    
    model = lgb.train(params, lgb_train,
                      valid_sets=[lgb_train, lgb_eval],
                      verbose_eval=10,
                      num_boost_round=1000,
                      early_stopping_rounds=10)
    
    oof_train[val_idx] = \
        model.predict(X_val, num_iteration=model.best_iteration)

    y_pred = model.predict(X_test, num_iteration=model.best_iteration)

    y_preds.append(y_pred)
    models.append(model)
# Out:
# ======== fold: 0 ========
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 11.2236	valid_1's l1: 11.3364
# [20]	training's l1: 9.9512	valid_1's l1: 10.081
# [30]	training's l1: 9.12995	valid_1's l1: 9.26386
# [40]	training's l1: 8.53947	valid_1's l1: 8.69954
# [50]	training's l1: 8.10873	valid_1's l1: 8.28879
# [60]	training's l1: 7.82259	valid_1's l1: 8.04443
# [70]	training's l1: 7.58898	valid_1's l1: 7.84878
# [80]	training's l1: 7.45876	valid_1's l1: 7.78415
# [90]	training's l1: 7.30855	valid_1's l1: 7.67516
# [100]	training's l1: 7.20058	valid_1's l1: 7.59853
# [110]	training's l1: 7.10907	valid_1's l1: 7.52855
# [120]	training's l1: 7.04206	valid_1's l1: 7.52862
# Early stopping, best iteration is:
# [113]	training's l1: 7.08652	valid_1's l1: 7.50895
# ======== fold: 1 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 11.444	valid_1's l1: 11.5142
# [20]	training's l1: 10.1133	valid_1's l1: 10.1954
# [30]	training's l1: 9.27557	valid_1's l1: 9.37472
# [40]	training's l1: 8.68835	valid_1's l1: 8.80629
# [50]	training's l1: 8.21521	valid_1's l1: 8.33434
# [60]	training's l1: 7.8993	valid_1's l1: 8.01538
# [70]	training's l1: 7.6512	valid_1's l1: 7.7765
# [80]	training's l1: 7.47087	valid_1's l1: 7.60496
# [90]	training's l1: 7.3471	valid_1's l1: 7.4907
# [100]	training's l1: 7.24391	valid_1's l1: 7.39718
# [110]	training's l1: 7.18509	valid_1's l1: 7.34568
# [120]	training's l1: 7.11603	valid_1's l1: 7.28476
# [130]	training's l1: 7.06574	valid_1's l1: 7.24497
# [140]	training's l1: 7.03147	valid_1's l1: 7.22048
# [150]	training's l1: 6.99369	valid_1's l1: 7.1892
# [160]	training's l1: 6.95878	valid_1's l1: 7.16013
# [170]	training's l1: 6.93196	valid_1's l1: 7.14075
# [180]	training's l1: 6.90246	valid_1's l1: 7.11926
# [190]	training's l1: 6.87157	valid_1's l1: 7.094
# [200]	training's l1: 6.84591	valid_1's l1: 7.0744
# [210]	training's l1: 6.81574	valid_1's l1: 7.04993
# [220]	training's l1: 6.78618	valid_1's l1: 7.02748
# [230]	training's l1: 6.76999	valid_1's l1: 7.01824
# [240]	training's l1: 6.74611	valid_1's l1: 7.00001
# [250]	training's l1: 6.72625	valid_1's l1: 6.98392
# [260]	training's l1: 6.71215	valid_1's l1: 6.97746
# [270]	training's l1: 6.69754	valid_1's l1: 6.96673
# [280]	training's l1: 6.67383	valid_1's l1: 6.9472
# [290]	training's l1: 6.66281	valid_1's l1: 6.93947
# [300]	training's l1: 6.64556	valid_1's l1: 6.92671
# [310]	training's l1: 6.6252	valid_1's l1: 6.91056
# [320]	training's l1: 6.60752	valid_1's l1: 6.89944
# [330]	training's l1: 6.59381	valid_1's l1: 6.89084
# [340]	training's l1: 6.57591	valid_1's l1: 6.88035
# [350]	training's l1: 6.56055	valid_1's l1: 6.86855
# [360]	training's l1: 6.5425	valid_1's l1: 6.85757
# [370]	training's l1: 6.51346	valid_1's l1: 6.83399
# [380]	training's l1: 6.50148	valid_1's l1: 6.82789
# [390]	training's l1: 6.49137	valid_1's l1: 6.82433
# [400]	training's l1: 6.47882	valid_1's l1: 6.82016
# [410]	training's l1: 6.4691	valid_1's l1: 6.81459
# [420]	training's l1: 6.46023	valid_1's l1: 6.80978
# [430]	training's l1: 6.4493	valid_1's l1: 6.8044
# [440]	training's l1: 6.43755	valid_1's l1: 6.79646
# [450]	training's l1: 6.42915	valid_1's l1: 6.79323
# [460]	training's l1: 6.41148	valid_1's l1: 6.77987
# [470]	training's l1: 6.40494	valid_1's l1: 6.77889
# [480]	training's l1: 6.39064	valid_1's l1: 6.76876
# [490]	training's l1: 6.37167	valid_1's l1: 6.75449
# [500]	training's l1: 6.36155	valid_1's l1: 6.75091
# [510]	training's l1: 6.35381	valid_1's l1: 6.74881
# [520]	training's l1: 6.34748	valid_1's l1: 6.74692
# [530]	training's l1: 6.34209	valid_1's l1: 6.74695
# Early stopping, best iteration is:
# [523]	training's l1: 6.34478	valid_1's l1: 6.74611
# ======== fold: 2 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 11.4571	valid_1's l1: 11.5934
# [20]	training's l1: 10.1295	valid_1's l1: 10.2637
# [30]	training's l1: 9.31412	valid_1's l1: 9.45358
# [40]	training's l1: 8.74241	valid_1's l1: 8.89526
# [50]	training's l1: 8.37547	valid_1's l1: 8.54186
# [60]	training's l1: 8.05322	valid_1's l1: 8.23496
# [70]	training's l1: 7.85708	valid_1's l1: 8.05386
# [80]	training's l1: 7.67342	valid_1's l1: 7.884
# [90]	training's l1: 7.50147	valid_1's l1: 7.73011
# [100]	training's l1: 7.39329	valid_1's l1: 7.63454
# [110]	training's l1: 7.30135	valid_1's l1: 7.55563
# [120]	training's l1: 7.2288	valid_1's l1: 7.49207
# [130]	training's l1: 7.17289	valid_1's l1: 7.44762
# [140]	training's l1: 7.09408	valid_1's l1: 7.381
# [150]	training's l1: 7.04086	valid_1's l1: 7.33993
# [160]	training's l1: 7.01182	valid_1's l1: 7.31857
# [170]	training's l1: 6.98105	valid_1's l1: 7.29343
# [180]	training's l1: 6.94969	valid_1's l1: 7.27042
# [190]	training's l1: 6.92658	valid_1's l1: 7.25542
# [200]	training's l1: 6.90366	valid_1's l1: 7.23821
# [210]	training's l1: 6.88528	valid_1's l1: 7.22545
# [220]	training's l1: 6.86139	valid_1's l1: 7.20849
# [230]	training's l1: 6.82526	valid_1's l1: 7.1795
# [240]	training's l1: 6.79557	valid_1's l1: 7.15472
# [250]	training's l1: 6.77731	valid_1's l1: 7.14271
# [260]	training's l1: 6.75456	valid_1's l1: 7.12511
# [270]	training's l1: 6.73077	valid_1's l1: 7.10232
# [280]	training's l1: 6.71083	valid_1's l1: 7.08805
# [290]	training's l1: 6.69754	valid_1's l1: 7.08029
# [300]	training's l1: 6.68799	valid_1's l1: 7.07585
# [310]	training's l1: 6.67503	valid_1's l1: 7.06621
# [320]	training's l1: 6.66546	valid_1's l1: 7.06086
# [330]	training's l1: 6.65109	valid_1's l1: 7.0511
# [340]	training's l1: 6.63882	valid_1's l1: 7.04056
# [350]	training's l1: 6.62616	valid_1's l1: 7.03283
# [360]	training's l1: 6.61147	valid_1's l1: 7.02351
# [370]	training's l1: 6.59748	valid_1's l1: 7.01498
# [380]	training's l1: 6.58508	valid_1's l1: 7.00901
# [390]	training's l1: 6.57286	valid_1's l1: 7.00261
# [400]	training's l1: 6.56472	valid_1's l1: 6.99916
# [410]	training's l1: 6.55796	valid_1's l1: 6.99646
# [420]	training's l1: 6.5486	valid_1's l1: 6.99152
# [430]	training's l1: 6.54071	valid_1's l1: 6.9876
# [440]	training's l1: 6.52734	valid_1's l1: 6.97915
# [450]	training's l1: 6.51718	valid_1's l1: 6.9736
# [460]	training's l1: 6.51203	valid_1's l1: 6.97229
# [470]	training's l1: 6.50422	valid_1's l1: 6.9691
# [480]	training's l1: 6.49282	valid_1's l1: 6.9627
# [490]	training's l1: 6.48769	valid_1's l1: 6.96086
# [500]	training's l1: 6.48164	valid_1's l1: 6.95832
# [510]	training's l1: 6.47365	valid_1's l1: 6.95421
# [520]	training's l1: 6.46432	valid_1's l1: 6.94783
# [530]	training's l1: 6.45353	valid_1's l1: 6.94117
# [540]	training's l1: 6.4423	valid_1's l1: 6.93161
# [550]	training's l1: 6.43234	valid_1's l1: 6.92447
# [560]	training's l1: 6.42749	valid_1's l1: 6.92211
# [570]	training's l1: 6.42213	valid_1's l1: 6.92018
# [580]	training's l1: 6.41635	valid_1's l1: 6.91887
# [590]	training's l1: 6.41091	valid_1's l1: 6.91787
# [600]	training's l1: 6.40736	valid_1's l1: 6.91706
# [610]	training's l1: 6.40315	valid_1's l1: 6.91652
# [620]	training's l1: 6.39711	valid_1's l1: 6.91391
# [630]	training's l1: 6.3931	valid_1's l1: 6.914
# Early stopping, best iteration is:
# [621]	training's l1: 6.39659	valid_1's l1: 6.9139
# ======== fold: 3 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 11.5501	valid_1's l1: 11.6768
# [20]	training's l1: 10.2447	valid_1's l1: 10.3158
# [30]	training's l1: 9.48105	valid_1's l1: 9.51254
# [40]	training's l1: 8.81686	valid_1's l1: 8.82744
# [50]	training's l1: 8.42002	valid_1's l1: 8.41718
# [60]	training's l1: 8.08871	valid_1's l1: 8.08343
# [70]	training's l1: 7.82292	valid_1's l1: 7.82002
# [80]	training's l1: 7.65958	valid_1's l1: 7.65956
# [90]	training's l1: 7.52958	valid_1's l1: 7.5332
# [100]	training's l1: 7.42345	valid_1's l1: 7.42742
# [110]	training's l1: 7.34989	valid_1's l1: 7.35935
# [120]	training's l1: 7.29024	valid_1's l1: 7.30945
# [130]	training's l1: 7.23423	valid_1's l1: 7.25832
# [140]	training's l1: 7.19775	valid_1's l1: 7.22773
# [150]	training's l1: 7.14543	valid_1's l1: 7.18505
# [160]	training's l1: 7.10776	valid_1's l1: 7.15689
# [170]	training's l1: 7.04848	valid_1's l1: 7.10755
# [180]	training's l1: 7.01014	valid_1's l1: 7.08146
# [190]	training's l1: 6.98862	valid_1's l1: 7.06959
# [200]	training's l1: 6.95914	valid_1's l1: 7.04388
# [210]	training's l1: 6.93936	valid_1's l1: 7.03102
# [220]	training's l1: 6.92398	valid_1's l1: 7.01739
# [230]	training's l1: 6.89499	valid_1's l1: 6.99427
# [240]	training's l1: 6.87764	valid_1's l1: 6.97976
# [250]	training's l1: 6.85236	valid_1's l1: 6.95816
# [260]	training's l1: 6.8401	valid_1's l1: 6.94956
# [270]	training's l1: 6.82039	valid_1's l1: 6.9323
# [280]	training's l1: 6.80214	valid_1's l1: 6.91914
# [290]	training's l1: 6.77238	valid_1's l1: 6.89347
# [300]	training's l1: 6.74873	valid_1's l1: 6.87432
# [310]	training's l1: 6.73211	valid_1's l1: 6.86008
# [320]	training's l1: 6.72269	valid_1's l1: 6.85314
# [330]	training's l1: 6.70628	valid_1's l1: 6.84194
# [340]	training's l1: 6.69561	valid_1's l1: 6.83343
# [350]	training's l1: 6.68061	valid_1's l1: 6.82354
# [360]	training's l1: 6.67238	valid_1's l1: 6.82135
# [370]	training's l1: 6.66251	valid_1's l1: 6.81636
# [380]	training's l1: 6.65413	valid_1's l1: 6.81455
# [390]	training's l1: 6.64101	valid_1's l1: 6.80458
# [400]	training's l1: 6.63261	valid_1's l1: 6.79981
# [410]	training's l1: 6.62452	valid_1's l1: 6.79367
# [420]	training's l1: 6.61689	valid_1's l1: 6.78953
# [430]	training's l1: 6.61063	valid_1's l1: 6.78445
# [440]	training's l1: 6.60391	valid_1's l1: 6.7813
# [450]	training's l1: 6.59946	valid_1's l1: 6.77947
# [460]	training's l1: 6.5904	valid_1's l1: 6.7719
# [470]	training's l1: 6.58438	valid_1's l1: 6.76981
# [480]	training's l1: 6.57377	valid_1's l1: 6.76099
# [490]	training's l1: 6.5644	valid_1's l1: 6.7548
# [500]	training's l1: 6.55633	valid_1's l1: 6.7497
# [510]	training's l1: 6.55035	valid_1's l1: 6.74489
# [520]	training's l1: 6.54064	valid_1's l1: 6.73658
# [530]	training's l1: 6.53513	valid_1's l1: 6.73395
# [540]	training's l1: 6.52746	valid_1's l1: 6.72845
# [550]	training's l1: 6.52219	valid_1's l1: 6.72596
# [560]	training's l1: 6.51646	valid_1's l1: 6.72291
# [570]	training's l1: 6.50891	valid_1's l1: 6.71815
# [580]	training's l1: 6.49983	valid_1's l1: 6.71217
# [590]	training's l1: 6.49233	valid_1's l1: 6.70713
# [600]	training's l1: 6.48562	valid_1's l1: 6.703
# [610]	training's l1: 6.47793	valid_1's l1: 6.6972
# [620]	training's l1: 6.47068	valid_1's l1: 6.69247
# [630]	training's l1: 6.46451	valid_1's l1: 6.68848
# [640]	training's l1: 6.46063	valid_1's l1: 6.68656
# [650]	training's l1: 6.45577	valid_1's l1: 6.68484
# [660]	training's l1: 6.45023	valid_1's l1: 6.68231
# [670]	training's l1: 6.44482	valid_1's l1: 6.67974
# [680]	training's l1: 6.44048	valid_1's l1: 6.67855
# [690]	training's l1: 6.43393	valid_1's l1: 6.67496
# [700]	training's l1: 6.42971	valid_1's l1: 6.67346
# [710]	training's l1: 6.42476	valid_1's l1: 6.67147
# [720]	training's l1: 6.42056	valid_1's l1: 6.66919
# [730]	training's l1: 6.41644	valid_1's l1: 6.66629
# [740]	training's l1: 6.41239	valid_1's l1: 6.6648
# [750]	training's l1: 6.40676	valid_1's l1: 6.66174
# [760]	training's l1: 6.40284	valid_1's l1: 6.6599
# [770]	training's l1: 6.39718	valid_1's l1: 6.65618
# [780]	training's l1: 6.39267	valid_1's l1: 6.65337
# [790]	training's l1: 6.38927	valid_1's l1: 6.65181
# [800]	training's l1: 6.38567	valid_1's l1: 6.65096
# [810]	training's l1: 6.38285	valid_1's l1: 6.65018
# [820]	training's l1: 6.3797	valid_1's l1: 6.64864
# [830]	training's l1: 6.37553	valid_1's l1: 6.64578
# [840]	training's l1: 6.36994	valid_1's l1: 6.64145
# [850]	training's l1: 6.36725	valid_1's l1: 6.64106
# [860]	training's l1: 6.36226	valid_1's l1: 6.63789
# [870]	training's l1: 6.35696	valid_1's l1: 6.63494
# [880]	training's l1: 6.35103	valid_1's l1: 6.63009
# [890]	training's l1: 6.34771	valid_1's l1: 6.62844
# [900]	training's l1: 6.34462	valid_1's l1: 6.62735
# [910]	training's l1: 6.34061	valid_1's l1: 6.62619
# [920]	training's l1: 6.33362	valid_1's l1: 6.62103
# [930]	training's l1: 6.33155	valid_1's l1: 6.62076
# [940]	training's l1: 6.32855	valid_1's l1: 6.62006
# [950]	training's l1: 6.32563	valid_1's l1: 6.61928
# [960]	training's l1: 6.32276	valid_1's l1: 6.61786
# [970]	training's l1: 6.31783	valid_1's l1: 6.61425
# [980]	training's l1: 6.31527	valid_1's l1: 6.61272
# [990]	training's l1: 6.31212	valid_1's l1: 6.61088
# [1000]	training's l1: 6.30953	valid_1's l1: 6.61056
# Did not meet early stopping. Best iteration is:
# [1000]	training's l1: 6.30953	valid_1's l1: 6.61056
# ======== fold: 4 ========
# Training until validation scores don't improve for 10 rounds.
# [10]	training's l1: 11.5636	valid_1's l1: 11.4715
# [20]	training's l1: 10.2986	valid_1's l1: 10.2801
# [30]	training's l1: 9.47537	valid_1's l1: 9.53325
# [40]	training's l1: 8.82157	valid_1's l1: 8.93082
# [50]	training's l1: 8.41047	valid_1's l1: 8.56561
# [60]	training's l1: 8.08614	valid_1's l1: 8.26462
# [70]	training's l1: 7.83884	valid_1's l1: 8.0432
# [80]	training's l1: 7.66452	valid_1's l1: 7.8912
# [90]	training's l1: 7.52806	valid_1's l1: 7.76866
# [100]	training's l1: 7.42999	valid_1's l1: 7.68596
# [110]	training's l1: 7.32322	valid_1's l1: 7.59347
# [120]	training's l1: 7.25526	valid_1's l1: 7.53559
# [130]	training's l1: 7.20166	valid_1's l1: 7.49165
# [140]	training's l1: 7.16545	valid_1's l1: 7.45045
# [150]	training's l1: 7.12484	valid_1's l1: 7.42503
# [160]	training's l1: 7.07685	valid_1's l1: 7.38934
# [170]	training's l1: 7.03492	valid_1's l1: 7.35668
# [180]	training's l1: 7.00363	valid_1's l1: 7.33439
# [190]	training's l1: 6.97056	valid_1's l1: 7.31032
# [200]	training's l1: 6.94817	valid_1's l1: 7.2889
# [210]	training's l1: 6.93477	valid_1's l1: 7.27783
# [220]	training's l1: 6.9182	valid_1's l1: 7.26736
# [230]	training's l1: 6.89871	valid_1's l1: 7.25829
# [240]	training's l1: 6.88674	valid_1's l1: 7.24713
# [250]	training's l1: 6.87111	valid_1's l1: 7.24363
# [260]	training's l1: 6.85786	valid_1's l1: 7.23434
# [270]	training's l1: 6.8385	valid_1's l1: 7.22051
# [280]	training's l1: 6.81576	valid_1's l1: 7.20355
# [290]	training's l1: 6.80082	valid_1's l1: 7.19278
# [300]	training's l1: 6.78212	valid_1's l1: 7.17891
# [310]	training's l1: 6.7764	valid_1's l1: 7.1788
# [320]	training's l1: 6.75522	valid_1's l1: 7.16528
# [330]	training's l1: 6.74184	valid_1's l1: 7.1578
# [340]	training's l1: 6.73169	valid_1's l1: 7.15438
# [350]	training's l1: 6.72001	valid_1's l1: 7.14791
# [360]	training's l1: 6.70715	valid_1's l1: 7.14209
# [370]	training's l1: 6.69917	valid_1's l1: 7.13914
# [380]	training's l1: 6.69099	valid_1's l1: 7.13621
# [390]	training's l1: 6.67916	valid_1's l1: 7.12881
# [400]	training's l1: 6.66558	valid_1's l1: 7.12168
# [410]	training's l1: 6.65241	valid_1's l1: 7.11244
# [420]	training's l1: 6.64426	valid_1's l1: 7.10824
# [430]	training's l1: 6.63688	valid_1's l1: 7.10408
# [440]	training's l1: 6.62894	valid_1's l1: 7.10096
# [450]	training's l1: 6.62352	valid_1's l1: 7.09923
# [460]	training's l1: 6.61648	valid_1's l1: 7.09623
# [470]	training's l1: 6.60873	valid_1's l1: 7.09245
# [480]	training's l1: 6.60172	valid_1's l1: 7.08903
# [490]	training's l1: 6.59134	valid_1's l1: 7.08282
# [500]	training's l1: 6.58519	valid_1's l1: 7.08134
# [510]	training's l1: 6.57854	valid_1's l1: 7.07736
# [520]	training's l1: 6.57054	valid_1's l1: 7.07219
# [530]	training's l1: 6.56254	valid_1's l1: 7.06723
# [540]	training's l1: 6.55636	valid_1's l1: 7.06539
# [550]	training's l1: 6.5501	valid_1's l1: 7.06321
# [560]	training's l1: 6.54217	valid_1's l1: 7.05812
# [570]	training's l1: 6.53111	valid_1's l1: 7.04919
# [580]	training's l1: 6.52603	valid_1's l1: 7.04618
# [590]	training's l1: 6.51698	valid_1's l1: 7.04185
# [600]	training's l1: 6.51122	valid_1's l1: 7.03956
# [610]	training's l1: 6.50203	valid_1's l1: 7.03576
# [620]	training's l1: 6.49434	valid_1's l1: 7.03177
# [630]	training's l1: 6.49089	valid_1's l1: 7.03108
# [640]	training's l1: 6.48562	valid_1's l1: 7.03087
# Early stopping, best iteration is:
# [633]	training's l1: 6.48911	valid_1's l1: 7.02985

# %%
with open("../output/y_preds_002.pickle", "wb") as f:
    pickle.dump(y_preds, f)

# %%
with open("../output/models_002.pickle", "wb") as f:
    pickle.dump(models, f)

# %%
with open("../output/oof_train_002.pickle", "wb") as f:
    pickle.dump(oof_train, f)

# %%
plt.figure(figsize=(8, 4))
plt.hist(oof_train[cv_idx[0][1][0]:], bins=100, label="oof", alpha=0.5)
plt.hist(y_train.iloc[cv_idx[0][1][0]:], bins=100, label="y_train", alpha=0.5)
plt.legend()

# %%
scores = [
    m.best_score["valid_1"]["l1"] for m in models
]
score = sum(scores) / len(scores)
print("=== CV scores ===")
print(scores)
print(score)
# Out:
# === CV scores ===
# [7.508948507040992, 6.746112809531673, 6.91390038619125, 6.610559955113737, 7.029852822552529]
# 6.9618748960860355

# %%
submission = pd.read_csv("../input/sample_submission.csv")
submission.congestion = y_preds[-1]
submission.to_csv("../submit/submission_002.csv", index=False)
