# %%
use_colaboratory = True
if use_colaboratory:
    import os
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir('/content/drive/MyDrive/kaggle/tabular-playground-series-mar-2022/notebook')
# Out:
# Mounted at /content/drive

# %%
import json
with open('../../kaggle.json') as f:
    json_data = json.load(f)
    os.environ["KAGGLE_USERNAME"] = json_data["username"]
    os.environ["KAGGLE_KEY"] = json_data["key"]

# !pip install kaggle --upgrade
# !kaggle -v
# Out:
# ...
# Kaggle API 1.5.12

# %%
# download datasets
# !kaggle competitions download -c tabular-playground-series-mar-2022 -p ../input/
# !unzip "../input/*.zip" -d ../input/
# !rm ../input/*.zip
# Out:
# ...
#   0% 0.00/4.71M [00:00<?, ?B/s]
# 100% 4.71M/4.71M [00:00<00:00, 154MB/s]
# Archive:  ../input/tabular-playground-series-mar-2022.zip
#   inflating: ../input/sample_submission.csv
#   inflating: ../input/test.csv
#   inflating: ../input/train.csv

# %%
# submission
# !kaggle competitions submit tabular-playground-series-mar-2022 -f ../submit/submission_002.csv -m "002"
# Out:
# 100% 57.4k/57.4k [00:05<00:00, 11.1kB/s]
# Successfully submitted to Tabular Playground Series - Mar 2022
